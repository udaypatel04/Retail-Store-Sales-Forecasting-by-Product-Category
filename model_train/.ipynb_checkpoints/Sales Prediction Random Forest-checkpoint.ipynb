# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# ## Loading the data from csv file to Pandas DataFrame

# %%
df=pd.read_csv("../files/Train_data.csv")

# %%
df
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                FDP10          132          Low Fat         0.127470
# 1                DRI11          675          Low Fat         0.034238
# 2                FDW12          441          Regular         0.035400
# 3                FDC37          193          Low Fat         0.057557
# 4                FDC14          107          Regular         0.072222
# ...                ...          ...              ...              ...
# 103704           FDF22          171          Low Fat         0.056783
# 103705           FDS36          747          Regular         0.046982
# 103706           NCJ29          971          Low Fat         0.035186
# 103707           FDN46          855          Regular         0.145221
# 103708           DRG01          474          Low Fat         0.044878
#
#                  Item_Type     Item_MRP Outlet_Identifier  \
# 0              Snack Foods   224.029874            OUT027
# ...

# %%
df.shape
# Out:
# (103709, 13)

# %%
df['Outlet_Age']=df['Years']-df['Outlet_Establishment_Year']

# %%
df=df.drop(columns='Years')

# %%
df
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                FDP10          132          Low Fat         0.127470
# 1                DRI11          675          Low Fat         0.034238
# 2                FDW12          441          Regular         0.035400
# 3                FDC37          193          Low Fat         0.057557
# 4                FDC14          107          Regular         0.072222
# ...                ...          ...              ...              ...
# 103704           FDF22          171          Low Fat         0.056783
# 103705           FDS36          747          Regular         0.046982
# 103706           NCJ29          971          Low Fat         0.035186
# 103707           FDN46          855          Regular         0.145221
# 103708           DRG01          474          Low Fat         0.044878
#
#                  Item_Type     Item_MRP Outlet_Identifier  \
# 0              Snack Foods   224.029874            OUT027
# ...

# %%
df["Item_Type"].unique()
# Out:
# array(['Snack Foods', 'Hard Drinks', 'Baking Goods', 'Canned',
#        'Fruits and Vegetables', 'Dairy', 'Frozen Foods', 'Household',
#        'Breakfast', 'Soft Drinks', 'Meat', 'Health and Hygiene',
#        'Starchy Foods', 'Others', 'Seafood', 'Breads'], dtype=object)

# %%
df[df["Item_Type"] == 'Household']["Item_Identifier"].nunique()
# Out:
# 170

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103709 entries, 0 to 103708
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Item_Identifier            103709 non-null  object
#  1   Item_Weight                103709 non-null  int64
#  2   Item_Fat_Content           103709 non-null  object
#  3   Item_Visibility            103709 non-null  float64
#  4   Item_Type                  103709 non-null  object
#  5   Item_MRP                   103709 non-null  float64
#  6   Outlet_Identifier          103709 non-null  object
#  7   Outlet_Establishment_Year  103709 non-null  int64
#  8   Outlet_Size                103446 non-null  object
#  9   Outlet_Location_Type       103709 non-null  object
#  10  Outlet_Type                103709 non-null  object
#  11  Item_Outlet_Sales          103709 non-null  float64
#  12  Outlet_Age                 103709 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                    0
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                  263
# Outlet_Location_Type           0
# Outlet_Type                    0
# Item_Outlet_Sales              0
# Outlet_Age                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Filling missing values
# ### Outlet_Type (filling with mode)

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# np.int64(263)

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    51140
# Small     30870
# High      21436
# Name: count, dtype: int64

# %%
df['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
mode_of_outlet_size=df.pivot_table(values='Outlet_Size',columns='Outlet_Type', aggfunc= lambda x:x.mode()[0])

# %%
mode_of_outlet_size
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small              High            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
miss_values=df['Outlet_Size'].isnull()

# %%
miss_values.value_counts()
# Out:
# Outlet_Size
# False    103446
# True        263
# Name: count, dtype: int64

# %%
df.loc[miss_values,'Outlet_Size']=df.loc[miss_values,'Outlet_Type'].apply(lambda x: mode_of_outlet_size[x])

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Outlet_Age                   0
# dtype: int64

# %%
df.describe()
# Out:
#          Item_Weight  Item_Visibility       Item_MRP  \
# count  103709.000000    103709.000000  103709.000000
# mean      606.178046         0.068788     549.063469
# std       288.854397         0.054919     375.614051
# min       101.000000         0.000000      65.049663
# 25%       362.000000         0.027617     289.432971
# 50%       604.000000         0.055122     454.185529
# 75%       864.000000         0.097618     693.150282
# max      1099.000000         0.328391    2512.298973
#
#        Outlet_Establishment_Year  Item_Outlet_Sales     Outlet_Age
# count              103709.000000      103709.000000  103709.000000
# mean                 2007.072713        9811.691459       8.463643
# std                     7.485325        6093.006675       6.736165
# min                  2000.000000          64.238726       0.000000
# 25%                  2000.000000        5691.791757       3.000000
# 50%                  2002.000000        7770.453239       7.000000
# ...

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
#Item Weight Distribution
sns.set()
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(6,6))
sns.distplot(df['Item_Weight'])
plt.show()

# %%
#Item Visibility Distribution
plt.figure(figsize=(6,6))
sns.distplot(df['Item_Visibility'])
plt.show()

# %%
#Item MRP Distribution
plt.figure(figsize=(6,6))
sns.distplot(df['Item_MRP'])
plt.show()

# %%
#Item_Outlet_Sales Distribution
plt.figure(figsize=(6,6))
sns.distplot(df['Item_Outlet_Sales'])
plt.show()

# %%
 #Oultel_Establishment_Year Column
plt.figure(figsize=(6,6))
sns.countplot(x='Outlet_Establishment_Year',data=df)
plt.show()

# %%
 #Item_Fat_Content Column
plt.figure(figsize=(6,6))
sns.countplot(x='Item_Fat_Content',data=df)
plt.show()

# %%
 #Item_Type Column
plt.figure(figsize=(30,6))
sns.countplot(x='Item_Type',data=df)
plt.show()

# %%
 #Oultel_Size Column
plt.figure(figsize=(6,6))
sns.countplot(x='Outlet_Size',data=df)
plt.show()

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    67192
# Regular    36457
# low fat       25
# LF            22
# reg           13
# Name: count, dtype: int64

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace({'low fat':'Low Fat', 'LF':'Low Fat','reg':'Regular'})

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    67239
# Regular    36470
# Name: count, dtype: int64

# %% [markdown]
# ## Label Enconding

# %%
encoder=LabelEncoder()
df['Item_Identifier']=encoder.fit_transform(df['Item_Identifier'])
df['Item_Fat_Content']=encoder.fit_transform(df['Item_Fat_Content'])
df['Item_Type']=encoder.fit_transform(df['Item_Type'])
df['Outlet_Identifier']=encoder.fit_transform(df['Outlet_Identifier'])
df['Outlet_Size']=encoder.fit_transform(df['Outlet_Size'])
df['Outlet_Location_Type']=encoder.fit_transform(df['Outlet_Location_Type'])
df['Outlet_Type']=encoder.fit_transform(df['Outlet_Type'])

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              738          132                 0         0.127470         13
# 1               79          675                 0         0.034238          7
# 2             1076          441                 1         0.035400          0
# 3              259          193                 0         0.057557          0
# 4              244          107                 1         0.072222          3
#
#      Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  224.029874                  5                       2000            1
# 1  235.508052                  5                       2000            1
# 2  300.497426                  5                       2000            1
# 3  223.887676                  4                       2000            2
# 4   90.735652                  4                       2000            2
#
# ...

# %% [markdown]
# ## Splitting Data Into Test and Train Parts

# %%
X= df.drop(columns='Item_Outlet_Sales',axis=1)
Y=df['Item_Outlet_Sales']

# %%
X.shape
# Out:
# (103709, 12)

# %%
Y.shape
# Out:
# (103709,)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
df.sample(6)
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 9322               986          891                 1         0.245407
# 73495               13          346                 0         0.058091
# 73282              203          630                 0         0.036672
# 14842              456          288                 0         0.081614
# 55257               45          235                 0         0.000000
# 84905              297          660                 0         0.000000
#
#        Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 9322           0   248.223016                  4                       2000
# 73495          4   578.128124                  6                       2019
# 73282          5   628.248432                  8                       2012
# 14842          5   651.444139                  5                       2000
# 55257         14   583.605897                  7                       2017
# ...

# %% [markdown]
# ## Machine Learning Model Training

# %% [markdown]
# ### 1. RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
# Train Random Forest model
randomForestModel = RandomForestRegressor(n_estimators=100, random_state=42)
randomForestModel.fit(X_train, Y_train)
# Predict and calculate R²
y_pred = randomForestModel.predict(X_test)

# %%
y_pred
# Out:
# array([ 5075.81315321, 28173.8614979 ,  3964.7588419 , ...,
#        26991.61265904,  6945.03073687,  3148.73081401], shape=(20742,))

# %%
from sklearn.metrics import mean_absolute_error, r2_score
mae = mean_absolute_error(Y_test, y_pred)

# MAPE
mape = np.mean(np.abs((Y_test - y_pred) / Y_test)) * 100

# Print results
print(f"MAE      : {mae:.2f}")
print(f"MAPE     : {mape:.2f}%")
score = r2_score(Y_test, y_pred)
print(f"R² score on test set: {score*100:.2f}%")
# Out:
# MAE      : 1587.80
# MAPE     : 19.30%
# R² score on test set: 87.31%

# %% [markdown]
# ### Sales Prediction System

# %%
# input=(738,12.857645,0,0.127470,13,224.029874	,5,2000,1,2,3,	0)
# input=(79	,12.857645	,0	,0.034238	,7	,235.508052	,5	,2000	,1	,2	,3	,	0)

input=(259,	193,	0,	0.057557,	0,	223.887676,	4,	2000,	2,	0,	0,0	)
# input=(79,675	,0	,0.034238	,7	,235.508052	,5	,2000	,1	,2	,3,0	)

np_array=np.asarray(input,dtype=float)
prediction=randomForestModel.predict(np_array.reshape(1,-1))
print("sale prediction is :",prediction)
# Out:
# sale prediction is : [3666.29267752]

# %%
import joblib
joblib.dump(randomForestModel,'../models/randomForestModel.joblib',compress=9)
print("Model created")
# Out:
# Model created

# %%
# import pickle
# pickle.dump(randomForestModel,open('../models/randomForestModel.pkl','wb'))
# print("Model created")
# Out:
# Model created

# %%
# import matplotlib.pyplot as plt

# residuals = y_pred - Y_test

# for col in X_test.columns:
#     plt.figure(figsize=(6, 4))
#     plt.scatter(X_test[col], residuals, alpha=0.5)
#     plt.axhline(0, color='red', linestyle='--')
#     plt.title(f'Residuals vs {col}')
#     plt.xlabel(col)
#     plt.ylabel('Residuals')
#     plt.show()
